# %% [markdown]
# Applied Data Science Capstone Project - Week 1
#
# This is the preliminary exercise for the final project assigned to this course.

# %%
import pandas as pd
import numpy as np

# %%
# Print "Hello Capstone Project Course!"
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
